# %%
import requests
import pandas as pd

# %%
dados_api = requests.get("https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarPeriodo(dataInicial=@dataInicial,dataFinalCotacao=@dataFinalCotacao)?@dataInicial='01-01-2026'&@dataFinalCotacao='08-15-2026'&$top=100&$format=json&$select=cotacaoCompra,cotacaoVenda,dataHoraCotacao")

try:
    if dados_api.status_code == 200:
        dados_json = dados_api.json()
        display(dados_json)
    else:
        print(f"Erro na requisição: {dados_api.status_code}")
except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata$metadata#_CotacaoDolarPeriodo(cotacaoCompra,cotacaoVenda,dataHoraCotacao)',
#  'value': [{'cotacaoCompra': 5.4366,
#    'cotacaoVenda': 5.4372,
#    'dataHoraCotacao': '2026-01-02 13:03:33.254'},
#   {'cotacaoCompra': 5.4345,
#    'cotacaoVenda': 5.4351,
#    'dataHoraCotacao': '2026-01-05 13:10:14.896'},
#   {'cotacaoCompra': 5.3791,
#    'cotacaoVenda': 5.3797,
#    'dataHoraCotacao': '2026-01-06 13:12:07.358'},
#   {'cotacaoCompra': 5.3874,
#    'cotacaoVenda': 5.388,
#    'dataHoraCotacao': '2026-01-07 13:06:27.001'},
#   {'cotacaoCompra': 5.3854,
#    'cotacaoVenda': 5.386,
#    'dataHoraCotacao': '2026-01-08 13:04:28.616'},
#   {'cotacaoCompra': 5.3701,
#    'cotacaoVenda': 5.3707,
#    'dataHoraCotacao': '2026-01-09 13:09:29.054'},
#   {'cotacaoCompra': 5.3754,
#    'cotacaoVenda': 5.376,
#    'dataHoraCotacao': '2026-01-12 13:08:29.056'},
#   {'cotacaoCompra': 5.3758,
# ...
